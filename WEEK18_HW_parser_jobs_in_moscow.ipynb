# %%
import requests
import pandas as pd

# %%
# Get area id by name.
# Returns area id that is needed for vacancy requests.
# Trows RuntimeError if area is not found.
# Usage: msc_id = get_area_id_by_name('Москва')
def get_area_id_by_name(area_name):
    url = 'https://api.hh.ru/areas'
    areas_key = 'areas'
    id_key = 'id'
    name_key = 'name'

    response = requests.get(url)
    response_json = response.json()

    for area_town in response_json:
        if area_town[name_key] == area_name:
            return area_town[id_key]

        for area_state in area_town[areas_key]:
            if area_state[name_key] == area_name:
                return area_state[id_key]

            for area_city in area_state[areas_key]:
                if area_city[name_key] == area_name:
                    return area_city[id_key]

    raise RuntimeError(f"Cannot find provided area {area_name}")

# %%
# Gets a number of vacancies for given position in given area_id
# Usage count = get_vacancies_count('Data Analyst', get_area_id_by_name('Москва'))
# search_parameters can be found here: https://github.com/hhru/api/blob/master/docs/vacancies.md#поиск-по-вакансиям
def get_vacancies_count(position, area_id, search_parameters={}):
    url = 'https://api.hh.ru/vacancies'

    parameters = {
        'text': position,
        'area': area_id,
        'per_page': 2,
        'page': 1
    }
    all_parameters = {**parameters, **search_parameters}
    response = requests.get(url, params=all_parameters)
    vacancies_count = response.json()['found']
    return vacancies_count

minsk_id = get_area_id_by_name('Минск')
get_vacancies_count('Data Analyst', minsk_id, {"employment": "full"})
# Out:
# 86

# %%
# Download all vacancies for given position in given area_id
# Returns a list of json format with vacancies info
# Usage: vacancies = download_vacancies('Data Analyst', get_area_id_by_name('Москва'))
# search_parameters can be found here: https://github.com/hhru/api/blob/master/docs/vacancies.md#поиск-по-вакансиям
def download_vacancies(position, area_id, search_parameters={}):
    vacancies_count = get_vacancies_count(position, area_id, search_parameters)
    if vacancies_count == 0:
        return []

    url = 'https://api.hh.ru/vacancies'
    vacancies = []
    vacancies_per_page = 100
    pages_count = round(vacancies_count / vacancies_per_page)
    if pages_count == 0:
        pages_count = 1

    for page in range(0, pages_count):
        print(f"Parsing {page} page...")
        parameters = {
            'text': position,
            'area': area_id,
            'per_page': vacancies_per_page,
            'page': page
        }
        all_parameters = {**parameters, **search_parameters}
        response = requests.get(url, params=all_parameters)
        vacancies += response.json()['items']

    return vacancies

minsk_id = get_area_id_by_name('Минск')
vacancies = download_vacancies('Data Analyst', minsk_id, {"employment": "full"})
print(vacancies[5])
# Out:
# Parsing 0 page...
# {'id': '38783919', 'premium': False, 'name': 'Data Analyst', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '1002', 'name': 'Минск', 'url': 'https://api.hh.ru/areas/1002'}, 'salary': None, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': {'city': 'Минск', 'street': 'Зыбицкая улица', 'building': '10', 'description': None, 'lat': 53.906337, 'lng': 27.556603, 'raw': 'Минск, Зыбицкая улица, 10', 'metro': {'station_name': 'Немига', 'line_name': 'Автозаводская', 'station_id': '63.422', 'line_id': '63', 'lat': 53.905615, 'lng': 27.55415}, 'metro_stations': [{'station_name': 'Немига', 'line_name': 'Автозаводская', 'station_id': '63.422', 'line_id': '63', 'lat': 53.905615, 'lng': 27.55415}], 'id': '1733385'}, 'response_url': None, 'sort_point_distance': None, 'employer': {'id': '3603119', 'name': 'Апподил', 'url': 'https://api.hh.ru/employers/3603119', 'alternate_url': 'https://hh.ru/employer/3603119', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/645605.png', '90': 'https://hhcdn.ru/employer-logo/3023568.png', '240': 'https://hhcdn.ru/employer-logo/3023569.png'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3603119', 'trusted': True}, 'published_at': '2020-08-24T11:21:36+0300', 'created_at': '2020-08-24T11:21:36+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38783919', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/38783919?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/38783919', 'relations': [], 'snippet': {'requirement': 'понимание продуктовой и монетизационной <highlighttext>аналитики</highlighttext> мобильных приложений. - опыт решения <highlighttext>Data</highlighttext> Science и Machine Learning задач. - опыт работы с инструментами <highlighttext>аналитики</highlighttext>...', 'responsibility': 'Работать с источниками данных в сыром виде, понимать, как устроено хранение данных. Сбор, подготовка, анализ данных, представление и визуализация результата. - '}, 'contacts': None, 'schedule': {'id': 'fullDay', 'name': 'Полный день'}, 'working_days': [], 'working_time_intervals': [], 'working_time_modes': [], 'accept_temporary': False}

# %%
moscow_id = get_area_id_by_name('Москва')
minsk_id = get_area_id_by_name('Минск')

print(get_vacancies_count('data analyst', moscow_id))

# Each vacancy has such fields (they may be NULL) as
# ['name'] : str,
# ['salary']['from'] : int,
# ['salary']['to'] : int,
# ['salary']['gross'] : boolean,
# ['salary']['currency'] : str (RUR, BYN, USD, EUR, etc),
# ['snippet']['requirement'] : str
# ['snippet']['responsibility'] : str
# The full list of fields is described here: https://github.com/hhru/api/blob/master/docs/vacancies.md#ответ-1
vacancies = download_vacancies('Data analyst', moscow_id)

print(vacancies[0]['salary']['from'])
# Out:
# 886
# Parsing 0 page...
# Parsing 1 page...
# Parsing 2 page...
# Parsing 3 page...
# Parsing 4 page...
# Parsing 5 page...
# Parsing 6 page...
# Parsing 7 page...
# Parsing 8 page...
# 100000

# %%
vacancies
# Out:
# [{'id': '38812932',
#   'premium': False,
#   'name': 'Analyst/Consultant',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 100000, 'to': 250000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '4460664',
#    'name': 'Senteo Inc',
#    'url': 'https://api.hh.ru/employers/4460664',
#    'alternate_url': 'https://hh.ru/employer/4460664',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/709016.png',
#     '90': 'https://hhcdn.ru/employer-logo/3277180.png',
#     '240': 'https://hhcdn.ru/employer-logo/3277181.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4460664',
#    'trusted': True},
#   'published_at': '2020-08-25T11:31:05+0300',
#   'created_at': '2020-08-25T11:31:05+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38812932',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38812932?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38812932',
#   'relations': [],
#   'snippet': {'requirement': 'Deep knowledge of Excel and working with <highlighttext>data</highlighttext> from various sources (both internal and external). Deep knowledge of Power Point...',
#    'responsibility': None},
#   'contacts': None,
#   'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38284507',
#   'premium': False,
#   'name': 'Data Analyst (Digital)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 2700, 'to': 3400, 'currency': 'EUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '1312113',
#    'name': 'Exness',
#    'url': 'https://api.hh.ru/employers/1312113',
#    'alternate_url': 'https://hh.ru/employer/1312113',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/992741.png',
#     '240': 'https://hhcdn.ru/employer-logo/992742.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/43236.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1312113',
#    'trusted': True},
#   'published_at': '2020-08-27T10:58:04+0300',
#   'created_at': '2020-08-27T10:58:04+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38284507',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38284507?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38284507',
#   'relations': [],
#   'snippet': {'requirement': 'Being able to formalize and visualize the results of the <highlighttext>data</highlighttext> analysis. Ability to organize and prioritize tasks efficiently and...',
#    'responsibility': 'Deliver actionable, <highlighttext>data</highlighttext>-driven quantitative analyses in the digital acquisitions team. General <highlighttext>data</highlighttext> and market analysis for projects. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38800310',
#   'premium': False,
#   'name': 'Data Analyst в Пикабу (удаленно)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 70000, 'to': 130000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '1583540',
#    'name': 'Пикабу',
#    'url': 'https://api.hh.ru/employers/1583540',
#    'alternate_url': 'https://hh.ru/employer/1583540',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2804608.png',
#     '90': 'https://hhcdn.ru/employer-logo/2804607.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/590838.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1583540',
#    'trusted': True},
#   'published_at': '2020-08-24T17:59:43+0300',
#   'created_at': '2020-08-24T17:59:43+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38800310',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38800310?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38800310',
#   'relations': [],
#   'snippet': {'requirement': 'Уверенный SQL. Базовый Python + Pandas. Матстат для проверки гипотез. Релевантный опыт: пет-проект/разработка на python. Будет плюсом знание...',
#    'responsibility': 'Анализировать пользовательское поведение - поиск точек роста и аномалий. Помогать продуктовой команде с проведением А/Б тестов - дизайн эксперимента, анализ результатов. '},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38368600',
#   'premium': False,
#   'name': 'Руководитель департамента data аналитики',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 280000, 'to': 300000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Пречистенская набережная',
#    'building': '17-19',
#    'description': None,
#    'lat': 55.739732,
#    'lng': 37.605508,
#    'raw': 'Москва, Пречистенская набережная, 17-19',
#    'metro': {'station_name': 'Кропоткинская',
#     'line_name': 'Сокольническая',
#     'station_id': '1.64',
#     'line_id': '1',
#     'lat': 55.745297,
#     'lng': 37.604217},
#    'metro_stations': [{'station_name': 'Кропоткинская',
#      'line_name': 'Сокольническая',
#      'station_id': '1.64',
#      'line_id': '1',
#      'lat': 55.745297,
#      'lng': 37.604217},
#     {'station_name': 'Парк культуры',
#      'line_name': 'Сокольническая',
#      'station_id': '1.103',
#      'line_id': '1',
#      'lat': 55.736163,
#      'lng': 37.595027}],
#    'id': '632566'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2077620',
#    'name': 'Центр 2М',
#    'url': 'https://api.hh.ru/employers/2077620',
#    'alternate_url': 'https://hh.ru/employer/2077620',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2868545.png',
#     '90': 'https://hhcdn.ru/employer-logo/2868544.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/606848.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2077620',
#    'trusted': True},
#   'published_at': '2020-08-24T13:46:42+0300',
#   'created_at': '2020-08-24T13:46:42+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38368600',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38368600?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38368600',
#   'relations': [],
#   'snippet': {'requirement': 'Умение ставить и контролировать качество выполнения задач <highlighttext>аналитиками</highlighttext> данных; Проактивность, ответственность и ориентированность на результат. Обязательно высшее математическое образование. ',
#    'responsibility': 'Участие в роли <highlighttext>аналитика</highlighttext> данных в проектировании архитектуры, выработке решений по отказоустойчивости и производительности сервисов. Презентация результатов исследований Заказчикам, подготовка...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38801205',
#   'premium': False,
#   'name': 'Intern, Data Science',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Варшавское шоссе',
#    'building': '9с1б',
#    'description': None,
#    'lat': 55.699837,
#    'lng': 37.623645,
#    'raw': 'Москва, Варшавское шоссе, 9с1б',
#    'metro': {'station_name': 'Тульская',
#     'line_name': 'Серпуховско-Тимирязевская',
#     'station_id': '9.142',
#     'line_id': '9',
#     'lat': 55.70961,
#     'lng': 37.622569},
#    'metro_stations': [{'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569}],
#    'id': '355899'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '27937',
#    'name': 'Align Technology',
#    'url': 'https://api.hh.ru/employers/27937',
#    'alternate_url': 'https://hh.ru/employer/27937',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2227472.png',
#     '90': 'https://hhcdn.ru/employer-logo/2227471.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/446376.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=27937',
#    'trusted': True},
#   'published_at': '2020-08-24T18:54:55+0300',
#   'created_at': '2020-08-24T18:54:55+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38801205',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38801205?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38801205',
#   'relations': [],
#   'snippet': {'requirement': 'Знание методов статистического анализа: аппарат проверки гипотез, регрессии, деревья решений, методы кластеризации. Знание SQL. Английский – intermediate+. Базовое знание инструментов статистического...',
#    'responsibility': 'Предиктивная <highlighttext>аналитика</highlighttext>, root cause analysis: выявление факторов, оказывающих значительное влияние на исход ортодонтического лечения. Текстовая <highlighttext>аналитика</highlighttext>: sentiment analysis, topic modeling. '},
#   'contacts': None,
#   'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38732890',
#   'premium': False,
#   'name': 'Python Data Scientist',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Никольская улица',
#    'building': '10',
#    'description': None,
#    'lat': 55.757957,
#    'lng': 37.624534,
#    'raw': 'Москва, Никольская улица, 10',
#    'metro': {'station_name': 'Кузнецкий мост',
#     'line_name': 'Таганско-Краснопресненская',
#     'station_id': '7.67',
#     'line_id': '7',
#     'lat': 55.761498,
#     'lng': 37.624423},
#    'metro_stations': [{'station_name': 'Кузнецкий мост',
#      'line_name': 'Таганско-Краснопресненская',
#      'station_id': '7.67',
#      'line_id': '7',
#      'lat': 55.761498,
#      'lng': 37.624423},
#     {'station_name': 'Лубянка',
#      'line_name': 'Сокольническая',
#      'station_id': '1.66',
#      'line_id': '1',
#      'lat': 55.759889,
#      'lng': 37.625336},
#     {'station_name': 'Площадь Революции',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.100',
#      'line_id': '3',
#      'lat': 55.756741,
#      'lng': 37.62236},
#     {'station_name': 'Театральная',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.99',
#      'line_id': '2',
#      'lat': 55.758808,
#      'lng': 37.61768}],
#    'id': '2333708'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '5552',
#    'name': 'Web Interactive World',
#    'url': 'https://api.hh.ru/employers/5552',
#    'alternate_url': 'https://hh.ru/employer/5552',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/646404.png',
#     '90': 'https://hhcdn.ru/employer-logo/3026764.png',
#     '240': 'https://hhcdn.ru/employer-logo/3026765.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5552',
#    'trusted': True},
#   'published_at': '2020-08-26T14:10:07+0300',
#   'created_at': '2020-08-26T14:10:07+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38732890',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38732890?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38732890',
#   'relations': [],
#   'snippet': {'requirement': 'Умеете программировать на Python. Не боитесь сложной математики и можете разобраться со статьёй на arxiv и повторить это в коде. ',
#    'responsibility': 'Потоковая обработка данных. Тематическое моделирование. Построение моделей объектной тональности. Решать задачи на стыке графовых структур и ML. Работать с семантикой...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38428853',
#   'premium': False,
#   'name': 'Data Scientist',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 100000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Ленинградский проспект',
#    'building': '74А',
#    'description': None,
#    'lat': 55.80694,
#    'lng': 37.516925,
#    'raw': 'Москва, Ленинградский проспект, 74А',
#    'metro': {'station_name': 'Сокол',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.133',
#     'line_id': '2',
#     'lat': 55.805564,
#     'lng': 37.515245},
#    'metro_stations': [{'station_name': 'Сокол',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.133',
#      'line_id': '2',
#      'lat': 55.805564,
#      'lng': 37.515245}],
#    'id': '833104'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2887273',
#    'name': 'Retail Rocket',
#    'url': 'https://api.hh.ru/employers/2887273',
#    'alternate_url': 'https://hh.ru/employer/2887273',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2166871.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/431200.png',
#     '90': 'https://hhcdn.ru/employer-logo/2166870.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2887273',
#    'trusted': True},
#   'published_at': '2020-08-26T13:38:14+0300',
#   'created_at': '2020-08-26T13:38:14+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38428853',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38428853?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38428853',
#   'relations': [],
#   'snippet': {'requirement': 'Понимаешь принцип, что в большинстве случаев - решения простые. Имеешь опыт в веб-<highlighttext>аналитике</highlighttext>. Знаешь любой компилируемый язык. Имел опыт работы...',
#    'responsibility': 'Ad-hoc <highlighttext>аналитику</highlighttext> для решения локальных бизнес-задач. Разрабатывать ML модели для решения задач бизнеса (NLP, рекомендации, картинки). '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38801781',
#   'premium': False,
#   'name': 'Junior Data Analyst / Младший аналитик данных',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'проспект Вернадского',
#    'building': '6',
#    'description': None,
#    'lat': 55.692318578,
#    'lng': 37.5291039855,
#    'raw': 'Москва, проспект Вернадского, 6',
#    'metro': {'station_name': 'Университет',
#     'line_name': 'Сокольническая',
#     'station_id': '1.149',
#     'line_id': '1',
#     'lat': 55.69329,
#     'lng': 37.534511},
#    'metro_stations': [{'station_name': 'Университет',
#      'line_name': 'Сокольническая',
#      'station_id': '1.149',
#      'line_id': '1',
#      'lat': 55.69329,
#      'lng': 37.534511}],
#    'id': '3991700'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '4738222',
#    'name': 'IndexSol',
#    'url': 'https://api.hh.ru/employers/4738222',
#    'alternate_url': 'https://hh.ru/employer/4738222',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3457634.png',
#     '90': 'https://hhcdn.ru/employer-logo/3457633.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/754169.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4738222',
#    'trusted': False},
#   'published_at': '2020-08-24T19:59:45+0300',
#   'created_at': '2020-08-24T19:59:45+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38801781',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38801781?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38801781',
#   'relations': [],
#   'snippet': {'requirement': 'Студент последнего курса или выпускник экономического, математического или технического вуза. Хорошие математические навыки - статистика, теория вероятности. Углубленное знание и прикладные...',
#    'responsibility': 'Регулярный мониторинг работы расчетной инфраструктуры и сайта компании. Контроль и анализ результатов расчета. Выявление и документирование отклонений. Автоматизация внутренних рутинных...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38843890',
#   'premium': False,
#   'name': 'Стажер Data Scientist',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '78638',
#    'name': 'Тинькофф',
#    'url': 'https://api.hh.ru/employers/78638',
#    'alternate_url': 'https://hh.ru/employer/78638',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3452962.png',
#     '90': 'https://hhcdn.ru/employer-logo/3452961.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/753000.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=78638',
#    'trusted': True},
#   'published_at': '2020-08-26T13:28:21+0300',
#   'created_at': '2020-08-26T13:28:21+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38843890',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38843890?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38843890',
#   'relations': [],
#   'snippet': {'requirement': 'Умение доносить информацию простым языком, в том числе для тех, кто не разбирается в <highlighttext>аналитике</highlighttext> данных. Настрой на командную работу. ',
#    'responsibility': 'Построить устойчивый флоу передачи данных из источников, их обработки и визуализации в виде интерактивных дашбордов. Взаимодействовать с внутренними командами <highlighttext>аналитиков</highlighttext>...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '37793588',
#   'premium': False,
#   'name': 'Data Analyst',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '938231',
#    'name': 'Gett',
#    'url': 'https://api.hh.ru/employers/938231',
#    'alternate_url': 'https://hh.ru/employer/938231',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/1533506.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/272744.png',
#     '240': 'https://hhcdn.ru/employer-logo/1533507.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=938231',
#    'trusted': True},
#   'published_at': '2020-08-24T15:33:52+0300',
#   'created_at': '2020-08-24T15:33:52+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=37793588',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/37793588?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/37793588',
#   'relations': [],
#   'snippet': {'requirement': 'Minimum 3-5 years of experience as a business/<highlighttext>data</highlighttext> <highlighttext>analyst</highlighttext>. Strong analytical skills and <highlighttext>data</highlighttext>-driven thinking. ',
#    'responsibility': 'Payments analysis. Billing and pricing <highlighttext>data</highlighttext>-driven analysis. Analyze users, rides and payments <highlighttext>data</highlighttext> to find fraud patterns and anomalies. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38660521',
#   'premium': False,
#   'name': 'Data Scientist',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 120000, 'to': 170000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '4835563',
#    'name': 'КИБЕРБОРЕЯ',
#    'url': 'https://api.hh.ru/employers/4835563',
#    'alternate_url': 'https://hh.ru/employer/4835563',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4835563',
#    'trusted': True},
#   'published_at': '2020-08-26T21:17:31+0300',
#   'created_at': '2020-08-26T21:17:31+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38660521',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38660521?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38660521',
#   'relations': [],
#   'snippet': {'requirement': 'R или Python. Опыт работы по анализу данных. Знание и понимание алгоритмов машинного обучения. Знание и понимание математического моделирования и...',
#    'responsibility': 'Обработка и <highlighttext>аналитика</highlighttext> входных данных, их дальнейшая визуализация. Обработка разовых запросов. Разработка методик расчета для нестандартных показателей работы проектов. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38413809',
#   'premium': False,
#   'name': 'Data Scientist',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 120000, 'to': 180000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Западный административный округ, Можайский район, Инновационный центр Сколково, улица Нобеля',
#    'building': '1',
#    'description': None,
#    'lat': 55.684752,
#    'lng': 37.339337,
#    'raw': 'Москва, Западный административный округ, Можайский район, Инновационный центр Сколково, улица Нобеля, 1',
#    'metro': {'station_name': 'Славянский бульвар',
#     'line_name': 'Арбатско-Покровская',
#     'station_id': '3.176',
#     'line_id': '3',
#     'lat': 55.729542,
#     'lng': 37.470973},
#    'metro_stations': [{'station_name': 'Славянский бульвар',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.176',
#      'line_id': '3',
#      'lat': 55.729542,
#      'lng': 37.470973}],
#    'id': '2796132'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '1625656',
#    'name': 'СКАЙТРЭК',
#    'url': 'https://api.hh.ru/employers/1625656',
#    'alternate_url': 'https://hh.ru/employer/1625656',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/496931.jpg',
#     '90': 'https://hhcdn.ru/employer-logo/2429477.jpeg',
#     '240': 'https://hhcdn.ru/employer-logo/2429478.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1625656',
#    'trusted': True},
#   'published_at': '2020-08-25T18:25:05+0300',
#   'created_at': '2020-08-25T18:25:05+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38413809',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38413809?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38413809',
#   'relations': [],
#   'snippet': {'requirement': 'ОПЫТ_ЗНАНИЯ_НАВЫКИ. Высшее образование (Физическое/Математическое/Экономическое).',
#    'responsibility': 'Когнитивная платформа видео мониторинга и видео <highlighttext>аналитики</highlighttext>. Методы и алгоритмы <highlighttext>data</highlighttext> mining: кластеризация, регрессия, классификация; а также прикладного статистического анализа...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38851637',
#   'premium': False,
#   'name': 'Big Data Specialist',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '140083',
#    'name': 'Hyundai Motor CIS',
#    'url': 'https://api.hh.ru/employers/140083',
#    'alternate_url': 'https://hh.ru/employer/140083',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/528051.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/2553682.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/2553681.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=140083',
#    'trusted': True},
#   'published_at': '2020-08-26T17:13:50+0300',
#   'created_at': '2020-08-26T17:13:50+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38851637',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38851637?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38851637',
#   'relations': [],
#   'snippet': {'requirement': 'Understanding of <highlighttext>data</highlighttext> mining techniques, machine learning practices and <highlighttext>data</highlighttext> management conceptual apparatus (<highlighttext>Data</highlighttext> Model, <highlighttext>Data</highlighttext> Architecture, <highlighttext>Data</highlighttext> Flow Diagram...',
#    'responsibility': 'Support <highlighttext>analysts</highlighttext> at business units through regular meetings. Translate <highlighttext>data</highlighttext> into visualizations, improve existing dashboards. Extract actionable insights from large...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38686799',
#   'premium': False,
#   'name': 'Data Analyst (Python)',
#   'department': None,
#   'has_test': True,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'проспект Андропова',
#    'building': '18к3',
#    'description': None,
#    'lat': 55.6945,
#    'lng': 37.662021,
#    'raw': 'Москва, проспект Андропова, 18к3',
#    'metro': {'station_name': 'Технопарк',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.512',
#     'line_id': '2',
#     'lat': 55.695,
#     'lng': 37.664167},
#    'metro_stations': [{'station_name': 'Технопарк',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.512',
#      'line_id': '2',
#      'lat': 55.695,
#      'lng': 37.664167}],
#    'id': '602591'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '80',
#    'name': 'Альфа-Банк',
#    'url': 'https://api.hh.ru/employers/80',
#    'alternate_url': 'https://hh.ru/employer/80',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/663873.png',
#     '240': 'https://hhcdn.ru/employer-logo/3096625.png',
#     '90': 'https://hhcdn.ru/employer-logo/3096624.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=80',
#    'trusted': True},
#   'published_at': '2020-08-25T16:26:35+0300',
#   'created_at': '2020-08-25T16:26:35+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38686799',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38686799?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38686799',
#   'relations': [],
#   'snippet': {'requirement': 'Опыт работы с git. Знание принципов Agile/Kanban/Scrum. Опыт работы <highlighttext>data</highlighttext> <highlighttext>аналитиком</highlighttext> данных от 1 года. Отличное знание Python. ',
#    'responsibility': 'Поддержание и развивитие существующих алгоритмов/моделей. Реализация и мониторинг метрик. Написание отчетности. Разработка и выкат в прод моделей машинного обучения.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38854813',
#   'premium': False,
#   'name': 'BI Analyst / Solution Architect',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 150000, 'to': 200000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Пресненский Вал',
#    'building': '27с2',
#    'description': None,
#    'lat': 55.773024,
#    'lng': 37.570078,
#    'raw': 'Москва, улица Пресненский Вал, 27с2',
#    'metro': None,
#    'metro_stations': [],
#    'id': '3366939'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '3347569',
#    'name': 'Менажиева Гульжана Темерхановна',
#    'url': 'https://api.hh.ru/employers/3347569',
#    'alternate_url': 'https://hh.ru/employer/3347569',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2961140.png',
#     '240': 'https://hhcdn.ru/employer-logo/2961141.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/629997.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3347569',
#    'trusted': True},
#   'published_at': '2020-08-26T20:49:09+0300',
#   'created_at': '2020-08-26T20:49:09+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38854813',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38854813?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38854813',
#   'relations': [],
#   'snippet': {'requirement': '...BI <highlighttext>Analyst</highlighttext> / Web <highlighttext>Analyst</highlighttext>. 2+ years working with a BI reporting tools (Tableau, QlikView, PowerBI, Looker, Google <highlighttext>Data</highlighttext> Studio…). ',
#    'responsibility': '...high-load <highlighttext>data</highlighttext> pipelines that allow to automate <highlighttext>data</highlighttext> collection across hundreds of different <highlighttext>data</highlighttext> sources. We automate <highlighttext>data</highlighttext> transformation...'},
#   'contacts': {'name': 'Менажиева Гульжана',
#    'email': 'menajievagt@icloud.com',
#    'phones': [{'comment': 't.me/guljanamenajieva',
#      'city': '929',
#      'number': '6367069',
#      'country': '7'}]},
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '37419204',
#   'premium': False,
#   'name': 'Junior Data / Product Analyst (чат бот)',
#   'department': {'id': '2343-2343-it',
#    'name': 'Компания «СПОРТМАСТЕР», SM Lab'},
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2343',
#    'name': 'Спортмастер',
#    'url': 'https://api.hh.ru/employers/2343',
#    'alternate_url': 'https://hh.ru/employer/2343',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/232431.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/709767.png',
#     '90': 'https://hhcdn.ru/employer-logo/709766.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2343',
#    'trusted': True},
#   'published_at': '2020-08-26T12:45:29+0300',
#   'created_at': '2020-08-26T12:45:29+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=37419204',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/37419204?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/37419204',
#   'relations': [],
#   'snippet': {'requirement': 'Опыт работы на позиции <highlighttext>Data</highlighttext>/Product <highlighttext>аналитика</highlighttext> или DS – от 1года. Техническое / математическое образование. Аналитический склад ума, желание самостоятельно...',
#    'responsibility': 'Анализировать данные обращений пользователей в колл-центр и цифровые каналы (сайт, мобильное приложение, соцсети). Классифицировать ситуации пользователей, выделять ключевые тематики. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '37365664',
#   'premium': False,
#   'name': 'Junior Macro Analyst',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '7944',
#    'name': 'Совкомбанк',
#    'url': 'https://api.hh.ru/employers/7944',
#    'alternate_url': 'https://hh.ru/employer/7944',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/230374.gif',
#     '90': 'https://hhcdn.ru/employer-logo/289053.png',
#     '240': 'https://hhcdn.ru/employer-logo/289195.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=7944',
#    'trusted': True},
#   'published_at': '2020-08-24T18:31:36+0300',
#   'created_at': '2020-08-24T18:31:36+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=37365664',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/37365664?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/37365664',
#   'relations': [],
#   'snippet': {'requirement': 'Higher education (degree in math/physics in top universities is preferable). Ability to process huge <highlighttext>data</highlighttext> flows. Excellent analytical skills. ',
#    'responsibility': 'Macroeconomic models development (inflation, balance of payments, etc.) for Russia and other countries. World corporate profits calculations. On demand ad...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38869122',
#   'premium': False,
#   'name': 'Web Analyst/Insights',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Краснопролетарская улица',
#    'building': '16с1',
#    'description': None,
#    'lat': 55.776978,
#    'lng': 37.60752,
#    'raw': 'Москва, Краснопролетарская улица, 16с1',
#    'metro': {'station_name': 'Достоевская',
#     'line_name': 'Люблинско-Дмитровская',
#     'station_id': '10.184',
#     'line_id': '10',
#     'lat': 55.781667,
#     'lng': 37.613889},
#    'metro_stations': [{'station_name': 'Достоевская',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.184',
#      'line_id': '10',
#      'lat': 55.781667,
#      'lng': 37.613889},
#     {'station_name': 'Менделеевская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.83',
#      'line_id': '9',
#      'lat': 55.781999,
#      'lng': 37.599141},
#     {'station_name': 'Новослободская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.82',
#      'line_id': '5',
#      'lat': 55.779606,
#      'lng': 37.601252}],
#    'id': '2862914'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '4176223',
#    'name': 'Stellar Labs',
#    'url': 'https://api.hh.ru/employers/4176223',
#    'alternate_url': 'https://hh.ru/employer/4176223',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/664144.png',
#     '240': 'https://hhcdn.ru/employer-logo/3097709.png',
#     '90': 'https://hhcdn.ru/employer-logo/3097708.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4176223',
#    'trusted': True},
#   'published_at': '2020-08-27T13:36:51+0300',
#   'created_at': '2020-08-27T13:36:51+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38869122',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38869122?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38869122',
#   'relations': [],
#   'snippet': {'requirement': 'Ability to validate analyses, reports, and underlying <highlighttext>data</highlighttext>, and collaborate with developers to resolve any reporting system <highlighttext>data</highlighttext> integrity issues. ',
#    'responsibility': '...<highlighttext>data</highlighttext> interpretation and help them in understanding our approach. Participate in projects on early implementation phases, validate it from <highlighttext>data</highlighttext>...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38700859',
#   'premium': False,
#   'name': 'Junior Data Engineer',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 100000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Усачёва улица',
#    'building': '33с1',
#    'description': None,
#    'lat': 55.723207,
#    'lng': 37.561113,
#    'raw': 'Москва, Усачёва улица, 33с1',
#    'metro': {'station_name': 'Лужники',
#     'line_name': 'МЦК',
#     'station_id': '95.535',
#     'line_id': '95',
#     'lat': 55.720278,
#     'lng': 37.563056},
#    'metro_stations': [{'station_name': 'Лужники',
#      'line_name': 'МЦК',
#      'station_id': '95.535',
#      'line_id': '95',
#      'lat': 55.720278,
#      'lng': 37.563056},
#     {'station_name': 'Спортивная',
#      'line_name': 'Сокольническая',
#      'station_id': '1.135',
#      'line_id': '1',
#      'lat': 55.722388,
#      'lng': 37.562041}],
#    'id': '1651801'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '3536900',
#    'name': 'Платформа ОФД',
#    'url': 'https://api.hh.ru/employers/3536900',
#    'alternate_url': 'https://hh.ru/employer/3536900',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2657470.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/2657469.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/553999.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3536900',
#    'trusted': True},
#   'published_at': '2020-08-25T12:07:21+0300',
#   'created_at': '2020-08-25T12:07:21+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38700859',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38700859?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38700859',
#   'relations': [],
#   'snippet': {'requirement': 'Высшее/неоконченное высшее образование. Опыт от 1 года решения реальных бизнес-задач в области сбора, хранения и анализа данных с...',
#    'responsibility': 'Работа на внутренних и внешних проектах компании в роли инженера и разработчика. Разработка ETL-процессов с использованием библиотеки Apache Spark...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38480330',
#   'premium': True,
#   'name': 'Продуктовый Аналитик / Product Analyst',
#   'department': None,
#   'has_test': True,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 150000, 'to': 180000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Академика Пилюгина',
#    'building': '22',
#    'description': None,
#    'lat': 55.669747,
#    'lng': 37.532143,
#    'raw': 'Москва, улица Академика Пилюгина, 22',
#    'metro': {'station_name': 'Калужская',
#     'line_name': 'Калужско-Рижская',
#     'station_id': '6.41',
#     'line_id': '6',
#     'lat': 55.656682,
#     'lng': 37.540075},
#    'metro_stations': [{'station_name': 'Калужская',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.41',
#      'line_id': '6',
#      'lat': 55.656682,
#      'lng': 37.540075},
#     {'station_name': 'Новые Черемушки',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.92',
#      'line_id': '6',
#      'lat': 55.670077,
#      'lng': 37.554493},
#     {'station_name': 'Проспект Вернадского',
#      'line_name': 'Сокольническая',
#      'station_id': '1.118',
#      'line_id': '1',
#      'lat': 55.676549,
#      'lng': 37.504584}],
#    'id': '810704'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2587283',
#    'name': 'ZAVOD Games',
#    'url': 'https://api.hh.ru/employers/2587283',
#    'alternate_url': 'https://hh.ru/employer/2587283',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/518548.png',
#     '240': 'https://hhcdn.ru/employer-logo/2515670.png',
#     '90': 'https://hhcdn.ru/employer-logo/2515669.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2587283',
#    'trusted': True},
#   'published_at': '2020-08-21T14:45:12+0300',
#   'created_at': '2020-08-21T14:45:12+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38480330',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38480330?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38480330',
#   'relations': [],
#   'snippet': {'requirement': 'Какие механики и какой контент нравятся игрокам и повышают их удовольствие от игры, а какие – не нравятся и расстраивают? ',
#    'responsibility': 'Где проблемные места в игре, на которых игроки уходят? Самостоятельно задать уточняющие вопросы. Спроектировать решение. Провести исследование. Написать запросы и...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38394461',
#   'premium': False,
#   'name': 'Analyst',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '1449599',
#    'name': 'Proxima Capital Group',
#    'url': 'https://api.hh.ru/employers/1449599',
#    'alternate_url': 'https://hh.ru/employer/1449599',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1664247.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/305469.bmp',
#     '90': 'https://hhcdn.ru/employer-logo/1664246.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1449599',
#    'trusted': True},
#   'published_at': '2020-08-25T10:04:09+0300',
#   'created_at': '2020-08-25T10:04:09+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38394461',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38394461?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38394461',
#   'relations': [],
#   'snippet': {'requirement': '1-3 year experience in investment banking / valuation / management consulting. Sound understanding of corporate finance and financial reporting. ',
#    'responsibility': 'Financial modelling and valuation. Drafting of marketing materials (pitchbooks, teasers and information memorandums). Market research and <highlighttext>data</highlighttext> analysis.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38814797',
#   'premium': False,
#   'name': 'Аналитик данных (Data Analyst)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': None,
#    'street': None,
#    'building': None,
#    'description': None,
#    'lat': None,
#    'lng': None,
#    'raw': None,
#    'metro': {'station_name': 'Юго-Западная',
#     'line_name': 'Сокольническая',
#     'station_id': '1.162',
#     'line_id': '1',
#     'lat': 55.663146,
#     'lng': 37.482852},
#    'metro_stations': [{'station_name': 'Юго-Западная',
#      'line_name': 'Сокольническая',
#      'station_id': '1.162',
#      'line_id': '1',
#      'lat': 55.663146,
#      'lng': 37.482852}],
#    'id': '1645217'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '3508081',
#    'name': 'Российская академия народного хозяйства и государственной службы при Президенте Российской Федерации',
#    'url': 'https://api.hh.ru/employers/3508081',
#    'alternate_url': 'https://hh.ru/employer/3508081',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2673950.png',
#     '90': 'https://hhcdn.ru/employer-logo/2673949.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/558119.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3508081',
#    'trusted': True},
#   'published_at': '2020-08-25T12:14:43+0300',
#   'created_at': '2020-08-25T12:14:43+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38814797',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38814797?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38814797',
#   'relations': [],
#   'snippet': {'requirement': 'Знания инструментов и подходов, используемых для анализа действий слушателей в образовательных материалах и других ресурсах Центра (Google <highlighttext>Аналитика</highlighttext>, Яндекс Метрика...',
# ...
#   'salary': {'from': 250000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '1111058',
#    'name': 'Star-staff',
#    'url': 'https://api.hh.ru/employers/1111058',
#    'alternate_url': 'https://hh.ru/employer/1111058',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/571707.png',
#     '90': 'https://hhcdn.ru/employer-logo/2728297.png',
#     '240': 'https://hhcdn.ru/employer-logo/2728298.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1111058',
#    'trusted': True},
#   'published_at': '2020-07-28T17:39:05+0300',
#   'created_at': '2020-07-28T17:39:05+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38282170',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38282170?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38282170',
#   'relations': [],
#   'snippet': {'requirement': 'Опыт проектирования архитектуры и доведения проекта до релиза. Опыт проектирования высоконагруженных систем. Опыт построения больших БД. Базовое понимание серверных и...',
#    'responsibility': 'Возможность консультаций у врача-терапевта прямо в офисе.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38302579',
#   'premium': False,
#   'name': 'Стажер в Центр развития финансовых технологий',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': None, 'to': 30000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Пресненская набережная',
#    'building': '10с2',
#    'description': None,
#    'lat': 55.74751,
#    'lng': 37.534954,
#    'raw': 'Москва, Пресненская набережная, 10с2',
#    'metro': {'station_name': 'Международная',
#     'line_name': 'Филевская',
#     'station_id': '4.179',
#     'line_id': '4',
#     'lat': 55.748324,
#     'lng': 37.533282},
#    'metro_stations': [{'station_name': 'Международная',
#      'line_name': 'Филевская',
#      'station_id': '4.179',
#      'line_id': '4',
#      'lat': 55.748324,
#      'lng': 37.533282}],
#    'id': '1698668'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '58320',
#    'name': 'Россельхозбанк',
#    'url': 'https://api.hh.ru/employers/58320',
#    'alternate_url': 'https://hh.ru/employer/58320',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/322665.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/219020.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/395522.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=58320',
#    'trusted': True},
#   'published_at': '2020-07-29T15:13:52+0300',
#   'created_at': '2020-07-29T15:13:52+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38302579',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38302579?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38302579',
#   'relations': [],
#   'snippet': {'requirement': '...и готовые работать не менее 4 часов в день по специальностям: Бизнес <highlighttext>аналитик</highlighttext>, Системный <highlighttext>аналитик</highlighttext>, Разработчик, DevOps, <highlighttext>Data</highlighttext> Scientist, Тестировщик.',
#    'responsibility': 'Обязанности и распределение по командам будут подобраны по результатам предварительного тестирования. Заключение договора от 3х месяцев.'},
#   'contacts': {'name': 'Галустов Давид Игоревич',
#    'email': 'galustovdi@rshb.ru',
#    'phones': [{'comment': None,
#      'city': '495',
#      'number': '7877787',
#      'country': '7'}]},
#   'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#   'working_days': [],
#   'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#     'name': 'Можно работать сменами по\xa04-6 часов в\xa0день'}],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38276456',
#   'premium': False,
#   'name': 'Руководитель направления по развитию клиентского опыта (массовый высокодоходный сегмент)',
#   'department': {'id': '3529-3529-prof', 'name': 'Сбербанк для экспертов'},
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '3529',
#    'name': 'Сбербанк',
#    'url': 'https://api.hh.ru/employers/3529',
#    'alternate_url': 'https://hh.ru/employer/3529',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/713736.png',
#     '90': 'https://hhcdn.ru/employer-logo/3296060.png',
#     '240': 'https://hhcdn.ru/employer-logo/3296061.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#    'trusted': True},
#   'published_at': '2020-07-28T14:42:21+0300',
#   'created_at': '2020-07-28T14:42:21+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38276456',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38276456?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38276456',
#   'relations': [],
#   'snippet': {'requirement': 'Высокий уровень работы с данными (анализировать самостоятельно, ставить задачи <highlighttext>аналитикам</highlighttext>, взаимодействовать с <highlighttext>Data</highlighttext> Scientist при подготовке моделей). Опыт сегментации, формирования...',
#    'responsibility': 'Развивать лояльность, стимулировать активность и управлять удержанием клиентов сегмента. Выстраивать комплексную коммуникацию с клиентами по этапам жизненного цикла (onboarding, сервисные...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38317813',
#   'premium': False,
#   'name': 'Руководитель направления',
#   'department': {'id': '3529-3529-prof', 'name': 'Сбербанк для экспертов'},
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '3529',
#    'name': 'Сбербанк',
#    'url': 'https://api.hh.ru/employers/3529',
#    'alternate_url': 'https://hh.ru/employer/3529',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/713736.png',
#     '90': 'https://hhcdn.ru/employer-logo/3296060.png',
#     '240': 'https://hhcdn.ru/employer-logo/3296061.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#    'trusted': True},
#   'published_at': '2020-07-30T11:45:14+0300',
#   'created_at': '2020-07-30T11:45:14+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38317813',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38317813?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38317813',
#   'relations': [],
#   'snippet': {'requirement': 'Опыт работы с аналитическими хранилищами, знание теории баз данных, хорошее знание SQL. Опыт работы с промышленными системами – внедрение, контроль качества...',
#    'responsibility': 'Для накопления и параллельной обработки больших объемов данных – Teradata, Hadoop, Greenplum. Для управления потоками ETL – Informatica, Oozie, Airflow, Nifi, также...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38412368',
#   'premium': False,
#   'name': 'Аналитик / Разработчик',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 80000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Мукомольный проезд',
#    'building': '4Ас2',
#    'description': None,
#    'lat': 55.751832,
#    'lng': 37.52527,
#    'raw': 'Москва, Мукомольный проезд, 4Ас2',
#    'metro': None,
#    'metro_stations': [],
#    'id': '630305'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2005098',
#    'name': 'ВБЦ',
#    'url': 'https://api.hh.ru/employers/2005098',
#    'alternate_url': 'https://hh.ru/employer/2005098',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/707340.JPG',
#     '90': 'https://hhcdn.ru/employer-logo/3270476.jpeg',
#     '240': 'https://hhcdn.ru/employer-logo/3270477.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2005098',
#    'trusted': True},
#   'published_at': '2020-08-04T17:19:43+0300',
#   'created_at': '2020-08-04T17:19:43+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38412368',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38412368?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38412368',
#   'relations': [],
#   'snippet': {'requirement': 'Делаем продукты для Бизнеса в России, может внукам не будет стыдно! Опыт в IT от 3х лет. JIRA/Confluence. ',
#    'responsibility': 'Создание эффективных технологий автоматизации закупочной деятельности. Получение информации с торговых площадок (Сбербанк-АСТ, РТС-Тендер, b2b-center.ru, ЕЭТП РосЭлТорг и любых...'},
#   'contacts': {'name': 'Трубицына Наталья',
#    'email': 'info@milcorp.ru',
#    'phones': [{'comment': None,
#      'city': '905',
#      'number': '5305780',
#      'country': '7'},
#     {'comment': None, 'city': '495', 'number': '2155743', 'country': '7'}]},
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38298974',
#   'premium': False,
#   'name': 'Аналитик-ресечер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': True,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Холодильный переулок',
#    'building': None,
#    'description': None,
#    'lat': 55.708688,
#    'lng': 37.624489,
#    'raw': 'Москва, Холодильный переулок',
#    'metro': {'station_name': 'Тульская',
#     'line_name': 'Серпуховско-Тимирязевская',
#     'station_id': '9.142',
#     'line_id': '9',
#     'lat': 55.70961,
#     'lng': 37.622569},
#    'metro_stations': [{'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569}],
#    'id': '2394913'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2495431',
#    'name': 'New.HR',
#    'url': 'https://api.hh.ru/employers/2495431',
#    'alternate_url': 'https://hh.ru/employer/2495431',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/625497.png',
#     '240': 'https://hhcdn.ru/employer-logo/2943141.png',
#     '90': 'https://hhcdn.ru/employer-logo/2943140.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2495431',
#    'trusted': True},
#   'published_at': '2020-07-29T13:42:39+0300',
#   'created_at': '2020-07-29T13:42:39+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38298974',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38298974?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38298974',
#   'relations': [],
#   'snippet': {'requirement': 'Вам нужно будет регулярно апдейтить ключевую информацию по отраслям и сферам бизнеса (преимущественно: ИТ и Интернет-бизнесы).',
#    'responsibility': 'Мы ищем <highlighttext>аналитика</highlighttext>, на задачи: анализа рынка, сбора данных о кандидатах, формирования точечной зарплатной <highlighttext>аналитики</highlighttext> и talent mapping. '},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38299113',
#   'premium': False,
#   'name': 'Специалист по контекстной рекламе / Директолог (Яндекс Директ, Google Adwords)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 30000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '3556368',
#    'name': 'Половинкин Иван Иванович',
#    'url': 'https://api.hh.ru/employers/3556368',
#    'alternate_url': 'https://hh.ru/employer/3556368',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3556368',
#    'trusted': True},
#   'published_at': '2020-07-29T13:46:41+0300',
#   'created_at': '2020-07-29T13:46:41+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38299113',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38299113?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38299113',
#   'relations': [],
#   'snippet': {'requirement': 'Умение пользоваться системами <highlighttext>аналитики</highlighttext>: Google Analytics, Яндекс Метрика, Calltouch, Callibri и другие (сегменты, цели, атрибуции и и т.д.). ',
#    'responsibility': 'Умение сокращать стоимость заявки (лида) или увеличивать их количество т.е. <highlighttext>аналитика</highlighttext> и оптимизация кампаний по разным метрикам: CPA, CPC...'},
#   'contacts': None,
#   'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '38298362',
#   'premium': False,
#   'name': 'IT рекрутер (middle/senior/lead)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': True,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'employer': {'id': '2495431',
#    'name': 'New.HR',
#    'url': 'https://api.hh.ru/employers/2495431',
#    'alternate_url': 'https://hh.ru/employer/2495431',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/625497.png',
#     '240': 'https://hhcdn.ru/employer-logo/2943141.png',
#     '90': 'https://hhcdn.ru/employer-logo/2943140.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2495431',
#    'trusted': True},
#   'published_at': '2020-07-29T13:26:01+0300',
#   'created_at': '2020-07-29T13:26:01+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=38298362',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/38298362?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/38298362',
#   'relations': [],
#   'snippet': {'requirement': '...вы специализировались на других Диджитал-профессиях, например: диджитал маркетинг, продакты, <highlighttext>аналитики</highlighttext>, дизайнеры и т.д. Вам нравится глубоко погружаться в...',
#    'responsibility': 'Делаем сервис анонимного поиска работы //geekjob.ru.'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False}]

# %%
# Create an empty dataframe with columns we want to get from json request
df = pd.DataFrame(columns=['Job_title', 'Salary', 'Organization', 'Metro_station', 'Job_description'])

# %%
# Fill in dataframe
for i in range(len(vacancies)):
    department = vacancies[i]['department']
    snippet = vacancies[i]['snippet']
    address = vacancies[i]['address']
    metro = address['metro'] if address else None
    
    df = df.append({'Job_title': vacancies[i]['name'],
                     'Salary': vacancies[i]['salary'],
                    'Organization': department['name'] if department else None,
                    'Metro_station': metro['station_name'] if metro else None,
                    'Job_description': snippet['requirement'] if snippet else None
                   }, ignore_index=True)

# %%
df.head()
# Out:
#                                   Job_title  \
# 0                        Analyst/Consultant
# 1                    Data Analyst (Digital)
# 2          Data Analyst в Пикабу (удаленно)
# 3  Руководитель департамента data аналитики
# 4                      Intern, Data Science
#
#                                               Salary Organization  \
# 0  {'from': 100000, 'to': 250000, 'currency': 'RU...         None
# 1  {'from': 2700, 'to': 3400, 'currency': 'EUR', ...         None
# 2  {'from': 70000, 'to': 130000, 'currency': 'RUR...         None
# 3  {'from': 280000, 'to': 300000, 'currency': 'RU...         None
# 4                                               None         None
#
#    Metro_station                                    Job_description
# 0           None  Deep knowledge of Excel and working with <high...
# 1           None  Being able to formalize and visualize the resu...
# 2           None  Уверенный SQL. Базовый Python + Pandas. Матста...
# 3  Кропоткинская  Умение ставить и контролировать качество выпол...
# 4       Тульская  Знание методов статистического анализа: аппара...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886 entries, 0 to 885
# Data columns (total 5 columns):
# Job_title          886 non-null object
# Salary             134 non-null object
# Organization       174 non-null object
# Metro_station      361 non-null object
# Job_description    883 non-null object
# dtypes: object(5)
# memory usage: 34.7+ KB
